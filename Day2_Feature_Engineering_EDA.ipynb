# %% [markdown]
# # Day 2 - Feature Engineering & Exploratory Data Analysis (EDA)
#
# ## Objective
# The objective of this notebook is to perform feature engineering and exploratory data analysis (EDA) on the cleaned Titanic dataset. New features will be created, categorical data will be encoded, and visualizations will be generated to understand the relationships among variables.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\cc\AppData\Local\Programs\Python\Python314\python.exe

# %%
import subprocess
import sys

subprocess.run([sys.executable, "-m", "pip", "install", "seaborn"])
# Out:
# CompletedProcess(args=['c:\\Users\\cc\\AppData\\Local\\Programs\\Python\\Python314\\python.exe', '-m', 'pip', 'install', 'seaborn'], returncode=0)

# %%
import seaborn as sns
print("Seaborn Installed Successfully!")
# Out:
# Seaborn Installed Successfully!

# %%
import pandas as pd

df = pd.read_csv("../Day 1/cleaned_train.csv")

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked
# 0      0         A/5 21171   7.2500  Unknown        S
# 1      0          PC 17599  71.2833      C85        C
# 2      0  STON/O2. 3101282   7.9250  Unknown        S
# 3      0            113803  53.1000     C123        S
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 703 entries, 0 to 702
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  703 non-null    int64
#  1   Survived     703 non-null    int64
#  2   Pclass       703 non-null    int64
#  3   Name         703 non-null    str
#  4   Sex          703 non-null    str
#  5   Age          703 non-null    float64
#  6   SibSp        703 non-null    int64
#  7   Parch        703 non-null    int64
#  8   Ticket       703 non-null    str
#  9   Fare         703 non-null    float64
#  10  Cabin        703 non-null    str
#  11  Embarked     703 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 66.0 KB

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   703.000000  703.000000  703.000000  703.000000  703.000000
# mean    449.290185    0.411095    2.244666   29.072077    0.519203
# std     258.604497    0.492383    0.835397   13.728478    0.934836
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     224.000000    0.000000    1.000000   20.000000    0.000000
# 50%     444.000000    0.000000    3.000000   28.000000    0.000000
# 75%     678.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   64.000000    5.000000
#
#             Parch        Fare
# count  703.000000  703.000000
# mean     0.435277   34.785093
# std      0.858015   53.255433
# min      0.000000    0.000000
# 25%      0.000000    8.050000
# 50%      0.000000   15.741700
# 75%      1.000000   33.000000
# max      6.000000  512.329200

# %%
# One-Hot Encoding
df = pd.get_dummies(df, columns=["Sex", "Embarked"], drop_first=True)

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare    Cabin  Sex_male  Embarked_Q  Embarked_S
# 0         A/5 21171   7.2500  Unknown      True       False        True
# 1          PC 17599  71.2833      C85     False       False       False
# 2  STON/O2. 3101282   7.9250  Unknown     False       False        True
# ...

# %%
plt.figure(figsize=(10,8))

sns.heatmap(df.select_dtypes(include=['number','bool']).corr(),
            annot=True,
            cmap="coolwarm")

plt.title("Correlation Heatmap")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.get_dummies(df, columns=["Sex", "Embarked"], drop_first=True)

df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = pd.get_dummies(df, columns=["Sex", "Embarked"], drop_first=True)
#       2
#       3 df.head()
#
# File c:\Users\cc\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\reshape\encoding.py:171, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     169     raise TypeError("Input must be a list-like for parameter `columns`")
#     170 else:
# --> 171     data_to_encode = data[columns]
#     173 # validate prefixes and separator to avoid silently dropping cols
#     174 def check_len(item, name: str) -> None:
#
# File c:\Users\cc\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
# ...

# %%
plt.figure(figsize=(10,8))

sns.heatmap(
    df.select_dtypes(include=['number', 'bool']).corr(),
    annot=True,
    cmap='coolwarm'
)

plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["Age"], bins=20, kde=True)

plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["Fare"], bins=20, kde=True)

plt.title("Fare Distribution")
plt.xlabel("Fare")
plt.ylabel("Count")

plt.show()

# %%
df.to_csv("features_v1.csv", index=False)

print("features_v1.csv saved successfully!")
# Out:
# features_v1.csv saved successfully!

# %%
df["Survived"].value_counts()
# Out:
# Survived
# 0    414
# 1    289
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,4))

sns.countplot(x="Survived", data=df)

plt.title("Survived Count")

plt.show()

# %%
plt.figure(figsize=(6,4))

sns.countplot(x="Sex", hue="Survived", data=df)

plt.title("Survival by Gender")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 3
#       1 plt.figure(figsize=(6,4))
#       2
# ----> 3 sns.countplot(x="Sex", hue="Survived", data=df)
#       4
#       5 plt.title("Survival by Gender")
#       6
#
# File c:\Users\cc\AppData\Local\Programs\Python\Python314\Lib\site-packages\seaborn\categorical.py:2631, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2628 elif x is not None and y is not None:
#    2629     raise TypeError("Cannot pass values for both `x` and `y`.")
# -> 2631 p = _CategoricalAggPlotter(
#    2632     data=data,
#    2633     variables=dict(x=x, y=y, hue=hue),
#    2634     order=order,
#    2635     orient=orient,
#    2636     color=color,
#    2637     legend=legend,
#    2638 )
# ...

# %%
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Sex_male', 'Embarked_Q', 'Embarked_S'],
#       dtype='str')

# %%
plt.figure(figsize=(6,4))

sns.countplot(x="Sex_male", hue="Survived", data=df)

plt.title("Survival by Gender")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["Age"], bins=30, kde=True)

plt.title("Age Distribution")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["Fare"], bins=30, kde=True)

plt.title("Fare Distribution")

plt.show()
